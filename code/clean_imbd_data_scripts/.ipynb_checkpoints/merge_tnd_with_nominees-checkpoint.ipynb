# %%
import pandas as pd
from os import path
import numpy as np

# %%
name_title_degree_clean_path = '../../data/imbd_data/name_title_degree_clean.csv'
the_oscar_award_corrected_path = '../../data/imbd_data/the_oscar_award_corrected.csv'
all_acting_path = '../../data/imbd_data/all_acting.csv'

# %%
def load_dataset(filepath):
    df = pd.read_csv(filepath)
    return df



def write_to_csv(df,filepath):
    '''
    input: df - a pandas DataFrame
           filepath - an output filepath as a string

    writes to a csv file
    in same diretory as this script

    returns: nothing
    '''
    # if no csv exists
    if not path.exists(filepath):
        df.to_csv(filepath,index=False)
    else:
        df.to_csv(filepath, mode='a', header=False,index=False)

# %%
# load data
name_title_degree_df = load_dataset(name_title_degree_clean_path)
kaggle_df = load_dataset(the_oscar_award_corrected_path)

# %%
# add num times nominated 
kaggle_df['num_times_nominated']=1
kaggle_num_nom = pd.DataFrame([],columns = kaggle_df.columns)
names = kaggle_df.name.unique()
for name in names:
    name_df = kaggle_df[kaggle_df.name==name]
    name_df = name_df.sort_values(by=['year_film'])
    num_times = list(range(1, len(name_df)+1))
    name_df['num_times_nominated'] = num_times
    kaggle_num_nom = kaggle_num_nom.append(name_df)

print(kaggle_num_nom)
# Out:
#       year_film year_ceremony ceremony   category                 name  \
# 0          1927          1928        1      ACTOR  Richard Barthelmess
# 1          1927          1928        1      ACTOR        Emil Jannings
# 2          1927          1928        1    ACTRESS       Louise Dresser
# 3          1927          1928        1    ACTRESS         Janet Gaynor
# 534        1937          1938       10    ACTRESS         Janet Gaynor
# ...         ...           ...      ...        ...                  ...
# 10415      2020          2021       93  DIRECTING           Chloé Zhao
# 10416      2020          2021       93  DIRECTING    Thomas Vinterberg
# 10417      2020          2021       93  DIRECTING        David Fincher
# 10418      2020          2021       93  DIRECTING      Lee Isaac Chung
# 10419      2020          2021       93  DIRECTING      Emerald Fennell
#
#                         film winner num_times_nominated
# 0                  The Noose  False                   1
# 1           The Last Command   True                   1
# 2            A Ship Comes In  False                   1
# 3                 7th Heaven   True                   1
# 534           A Star Is Born  False                   2
# ...                      ...    ...                 ...
# 10415              Nomadland   True                   1
# 10416          Another Round  False                   1
# 10417                   Mank  False                   1
# 10418                 Minari  False                   1
# 10419  Promising Young Woman  False                   1
#
# [10420 rows x 8 columns]

# %%
test = kaggle_num_nom[kaggle_num_nom.name=='20th Century-Fox']
print(test)
# Out:
#      year_film year_ceremony ceremony                    category  \
# 602       1937          1938       10      OUTSTANDING PRODUCTION
# 730       1938          1939       11      OUTSTANDING PRODUCTION
# 746       1938          1939       11    SHORT SUBJECT (One-reel)
# 1027      1940          1941       13      OUTSTANDING PRODUCTION
# 1202      1941          1942       14  OUTSTANDING MOTION PICTURE
# 1224      1941          1942       14    SHORT SUBJECT (One-reel)
# 1396      1942          1943       15  OUTSTANDING MOTION PICTURE
# 1402      1942          1943       15     SHORT SUBJECT (Cartoon)
# 1408      1942          1943       15    SHORT SUBJECT (One-reel)
# 1586      1943          1944       16  OUTSTANDING MOTION PICTURE
# 1580      1943          1944       16  OUTSTANDING MOTION PICTURE
# 1585      1943          1944       16  OUTSTANDING MOTION PICTURE
# 1755      1944          1945       17         BEST MOTION PICTURE
# 2030      1946          1947       19         BEST MOTION PICTURE
# 2134      1947          1948       20         BEST MOTION PICTURE
# 2136      1947          1948       20         BEST MOTION PICTURE
# 2246      1948          1949       21         BEST MOTION PICTURE
# 2356      1949          1950       22         BEST MOTION PICTURE
# 2355      1949          1950       22         BEST MOTION PICTURE
# 2469      1950          1951       23         BEST MOTION PICTURE
#
#                   name                      film winner num_times_nominated
# 602   20th Century-Fox            In Old Chicago  False                   1
# 730   20th Century-Fox  Alexander's Ragtime Band  False                   2
# 746   20th Century-Fox            Timber Toppers  False                   3
# 1027  20th Century-Fox       The Grapes of Wrath  False                   4
# 1202  20th Century-Fox   How Green Was My Valley   True                   5
# 1224  20th Century-Fox      Sagebrush and Silver  False                   6
# 1396  20th Century-Fox            The Pied Piper  False                   7
# 1402  20th Century-Fox           All Out for 'V'  False                   8
# 1408  20th Century-Fox         Desert Wonderland  False                   9
# 1586  20th Century-Fox    The Song of Bernadette  False                  10
# 1580  20th Century-Fox           Heaven Can Wait  False                  11
# 1585  20th Century-Fox       The Ox-Bow Incident  False                  12
# 1755  20th Century-Fox                    Wilson  False                  13
# 2030  20th Century-Fox          The Razor's Edge  False                  14
# 2134  20th Century-Fox     Gentleman's Agreement   True                  15
# 2136  20th Century-Fox    Miracle on 34th Street  False                  16
# 2246  20th Century-Fox             The Snake Pit  False                  17
# 2356  20th Century-Fox       Twelve O'Clock High  False                  18
# 2355  20th Century-Fox   A Letter to Three Wives  False                  19
# 2469  20th Century-Fox             All about Eve   True                  20

# %%
print(name_title_degree_df.head())
print(kaggle_num_nom.head())
print(len(kaggle_num_nom))
# Out:
#       nconst     tconst          name  birthYear  deathYear category  \
# 0  nm0000001  tt0025164  Fred Astaire       1899     1987.0    actor
# 1  nm0000001  tt0026942  Fred Astaire       1899     1987.0    actor
# 2  nm0000001  tt0027125  Fred Astaire       1899     1987.0    actor
# 3  nm0000001  tt0027630  Fred Astaire       1899     1987.0    actor
# 4  nm0000001  tt0028333  Fred Astaire       1899     1987.0    actor
#
#        primaryTitle     originalTitle  film_year gender  age  degree
# 0  The Gay Divorcee  The Gay Divorcee       1934      M   35       3
# 1           Roberta           Roberta       1935      M   36       6
# 2           Top Hat           Top Hat       1935      M   36       6
# 3  Follow the Fleet  Follow the Fleet       1936      M   37       9
# 4        Swing Time        Swing Time       1936      M   37       9
#     year_film year_ceremony ceremony category                 name  \
# 0        1927          1928        1    ACTOR  Richard Barthelmess
# 1        1927          1928        1    ACTOR        Emil Jannings
# 2        1927          1928        1  ACTRESS       Louise Dresser
# 3        1927          1928        1  ACTRESS         Janet Gaynor
# 534      1937          1938       10  ACTRESS         Janet Gaynor
#
#                  film winner num_times_nominated
# 0           The Noose  False                   1
# 1    The Last Command   True                   1
# 2     A Ship Comes In  False                   1
# 3          7th Heaven   True                   1
# 534    A Star Is Born  False                   2
# 10420

# %%
# merge kaggle nominees with name_title_degree data
df = pd.merge(name_title_degree_df, kaggle_num_nom, how='left', 
              left_on=['name','primaryTitle'], 
              right_on = ['name','film'])

# %%
#compare lengh with newly merged dataset 
print(len(df))
print(len(name_title_degree_df))
# Out:
# 9354828
# 9354812

# %%
# checkout merged data
print(df.head(1))
# Out:
#       nconst     tconst          name  birthYear  deathYear category_x  \
# 0  nm0000001  tt0025164  Fred Astaire       1899     1987.0      actor
#
#        primaryTitle     originalTitle  film_year gender  age  degree  \
# 0  The Gay Divorcee  The Gay Divorcee       1934      M   35       3
#
#   year_film year_ceremony ceremony category_y film winner num_times_nominated
# 0       NaN           NaN      NaN        NaN  NaN    NaN                 NaN

# %%
# compare nominee length vs original nominee dataset
print(len(kaggle_num_nom))
print(len(df[df.ceremony.notna()]))
# Out:
# 1729
# 1527

# %%
# checkout columns
print(df.head(1))
print(df.columns)
# Out:
#       nconst     tconst          name  birthYear  deathYear category_x  \
# 0  nm0000001  tt0025164  Fred Astaire       1899     1987.0      actor
#
#        primaryTitle     originalTitle  film_year gender  age  degree  \
# 0  The Gay Divorcee  The Gay Divorcee       1934      M   35       3
#
#   year_film year_ceremony ceremony category_y film winner num_times_nominated
# 0       NaN           NaN      NaN        NaN  NaN    NaN                 NaN
# Index(['nconst', 'tconst', 'name', 'birthYear', 'deathYear', 'category_x',
#        'primaryTitle', 'originalTitle', 'film_year', 'gender', 'age', 'degree',
#        'year_film', 'year_ceremony', 'ceremony', 'category_y', 'film',
#        'winner', 'num_times_nominated'],
#       dtype='object')

# %%
# include only relevant columns
df = df[['nconst', 'tconst', 'name', 'birthYear', 'deathYear', 
         'category_x','primaryTitle', 'originalTitle', 'film_year', 
         'gender', 'age', 'degree','year_ceremony', 'ceremony', 
         'category_y','winner', 'num_times_nominated']]

# %%
# fix column names
df.columns = ['nconst', 'tconst', 'name', 'birthYear', 'deathYear', 
         'profession','primaryTitle', 'originalTitle', 'film_year', 
         'gender', 'age', 'degree','year_ceremony', 'ceremony', 
         'category','winner', 'num_times_nominated']

# %%
# data sanity check
df[df.num_times_nominated>15]
# Out:
#           nconst     tconst          name  birthYear  deathYear profession  \
# 5928   nm0000095  tt0113819   Woody Allen       1935        NaN      actor
# 5931   nm0000095  tt0118954   Woody Allen       1935        NaN      actor
# 79097  nm0000658  tt1007029  Meryl Streep       1949        NaN    actress
# 79107  nm0000658  tt1135503  Meryl Streep       1949        NaN    actress
# 79124  nm0000658  tt1322269  Meryl Streep       1949        NaN    actress
# 79136  nm0000658  tt2180411  Meryl Streep       1949        NaN    actress
# 79145  nm0000658  tt4136084  Meryl Streep       1949        NaN    actress
# 79148  nm0000658  tt6294822  Meryl Streep       1949        NaN    actress
#
#                   primaryTitle            originalTitle  film_year gender  \
# 5928          Mighty Aphrodite         Mighty Aphrodite       1995      M
# 5931      Deconstructing Harry     Deconstructing Harry       1997      M
# 79097            The Iron Lady            The Iron Lady       2011      F
# 79107            Julie & Julia            Julie & Julia       2009      F
# 79124     August: Osage County     August: Osage County       2013      F
# 79136           Into the Woods           Into the Woods       2014      F
# 79145  Florence Foster Jenkins  Florence Foster Jenkins       2016      F
# 79148                 The Post                 The Post       2017      F
#
#        age  degree year_ceremony ceremony  \
# 5928    60      59          1996       68
# 5931    62      69          1998       70
# 79097   62     136          2012       84
# 79107   60     129          2010       82
# 79124   64     145          2014       86
# 79136   65     152          2015       87
# 79145   67     160          2017       89
# 79148   68     167          2018       90
#
#                                                 category winner  \
# 5928   WRITING (Screenplay Written Directly for the S...  False
# 5931   WRITING (Screenplay Written Directly for the S...  False
# 79097                          ACTRESS IN A LEADING ROLE   True
# 79107                          ACTRESS IN A LEADING ROLE  False
# 79124                          ACTRESS IN A LEADING ROLE  False
# 79136                       ACTRESS IN A SUPPORTING ROLE  False
# 79145                          ACTRESS IN A LEADING ROLE  False
# 79148                          ACTRESS IN A LEADING ROLE  False
#
#       num_times_nominated
# 5928                   16
# 5931                   17
# 79097                  17
# 79107                  16
# 79124                  18
# 79136                  19
# 79145                  20
# 79148                  21

# %%
write_to_csv(df,all_acting_path)
